# %% [markdown]
# # Data Processing and Merging Notebook

# %% [markdown]
#     This notebook contains the steps taken to process and merge employee data from multiple Excel sheets.
#     The process involves cleaning, merging, and analyzing data from different sources to achieve the final output.
#     Each step is explained in detail with accompanying code.

# %% [markdown]
# ## Step 1: Load and Clean Region Data with Nulls Calculation

# %%
import pandas as pd

# Load the 'Central USA' sheet from the original dataset
central_usa_df = pd.read_excel('Case 3 - Demand Managenet.xlsx', sheet_name='Central USA')

# Display the first few rows of the dataframe
central_usa_df.head()

# Calculate the number of nulls in each column
central_usa_nulls = central_usa_df.isnull().sum()
central_usa_nulls

# %% [markdown]
# ## Step 2: Clean the Central USA Region

# %%
# Drop the first two rows which are headers and unrelated data
central_usa_cleaned = central_usa_df.drop([0, 1])

# Rename the first column as 'Employee Code' and set it as the identifier
central_usa_cleaned.rename(columns={'Unnamed: 0': 'Employee Code'}, inplace=True)

# Reset index to easily navigate rows
central_usa_cleaned.reset_index(drop=True, inplace=True)

# Display the cleaned dataframe
central_usa_cleaned.head()

# %% [markdown]
# ## Step 3: Clean the Lat_Pa Region

# %%
# Load the 'Lat_Pa' sheet from the original dataset
lat_pa_df = pd.read_excel('Case 3 - Demand Managenet.xlsx', sheet_name='Lat_Pa')

# Drop the first two rows which are headers and unrelated data
lat_pa_cleaned = lat_pa_df.drop([0, 1])

# Rename the first column as 'Employee Code' and set it as the identifier
lat_pa_cleaned.rename(columns={'Unnamed: 0': 'Employee Code'}, inplace=True)

# Reset index to easily navigate rows
lat_pa_cleaned.reset_index(drop=True, inplace=True)

# Display the cleaned dataframe
lat_pa_cleaned.head()

# %% [markdown]
# ## Step 4: Clean the AF Region

# %%
# Load the 'AF' sheet from the original dataset
af_df = pd.read_excel('Case 3 - Demand Managenet.xlsx', sheet_name='AF')

# Drop the first two rows which are headers and unrelated data
af_cleaned = af_df.drop([0, 1])

# Rename the first column as 'Employee Code' and set it as the identifier
af_cleaned.rename(columns={'Unnamed: 0': 'Employee Code'}, inplace=True)

# Reset index to easily navigate rows
af_cleaned.reset_index(drop=True, inplace=True)

# Display the cleaned dataframe
af_cleaned.head()

# %% [markdown]
# ## Step 5: Clean the MEA Region

# %%
# Load the 'MEA' sheet from the original dataset
mea_df = pd.read_excel('Case 3 - Demand Managenet.xlsx', sheet_name='MEA')

# Drop the first two rows which are headers and unrelated data
mea_cleaned = mea_df.drop([0, 1])

# Rename the first column as 'Employee Code' and set it as the identifier
mea_cleaned.rename(columns={'Unnamed: 0': 'Employee Code'}, inplace=True)

# Reset index to easily navigate rows
mea_cleaned.reset_index(drop=True, inplace=True)

# Display the cleaned dataframe
mea_cleaned.head()

# %% [markdown]
# ## Step 6: Clean the MER Region

# %%
# Load the 'MER' sheet from the original dataset
mer_df = pd.read_excel('Case 3 - Demand Managenet.xlsx', sheet_name='MER')

# Drop the first two rows which are headers and unrelated data
mer_cleaned = mer_df.drop([0, 1])

# Rename the first column as 'Employee Code' and set it as the identifier
mer_cleaned.rename(columns={'Unnamed: 0': 'Employee Code'}, inplace=True)

# Reset index to easily navigate rows
mer_cleaned.reset_index(drop=True, inplace=True)

# Display the cleaned dataframe
mer_cleaned.head()

# %% [markdown]
# ## Step 7: Clean the CSE Region

# %%
# Load the 'CSE' sheet from the original dataset
cse_df = pd.read_excel('Case 3 - Demand Managenet.xlsx', sheet_name='CSE')

# Drop the first two rows which are headers and unrelated data
cse_cleaned = cse_df.drop([0, 1])

# Rename the first column as 'Employee Code' and set it as the identifier
cse_cleaned.rename(columns={'Unnamed: 0': 'Employee Code'}, inplace=True)

# Reset index to easily navigate rows
cse_cleaned.reset_index(drop=True, inplace=True)

# Display the cleaned dataframe
cse_cleaned.head()

# %% [markdown]
# ## Step 8: Clean the Subsaharan Region

# %%
# Load the 'Subsaharan' sheet from the original dataset
subsaharan_df = pd.read_excel('Case 3 - Demand Managenet.xlsx', sheet_name='Subsaharan')

# Drop the first two rows which are headers and unrelated data
subsaharan_cleaned = subsaharan_df.drop([0, 1])

# Rename the first column as 'Employee Code' and set it as the identifier
subsaharan_cleaned.rename(columns={'Unnamed: 0': 'Employee Code'}, inplace=True)

# Reset index to easily navigate rows
subsaharan_cleaned.reset_index(drop=True, inplace=True)

# Display the cleaned dataframe
subsaharan_cleaned.head()

# %% [markdown]
# ## Step 9: Clean the F_east Region

# %%
# Load the 'F_east' sheet from the original dataset
f_east_df = pd.read_excel('Case 3 - Demand Managenet.xlsx', sheet_name='F_east')

# Drop the first two rows which are headers and unrelated data
f_east_cleaned = f_east_df.drop([0, 1])

# Rename the first column as 'Employee Code' and set it as the identifier
f_east_cleaned.rename(columns={'Unnamed: 0': 'Employee Code'}, inplace=True)

# Reset index to easily navigate rows
f_east_cleaned.reset_index(drop=True, inplace=True)

# Display the cleaned dataframe
f_east_cleaned.head()
